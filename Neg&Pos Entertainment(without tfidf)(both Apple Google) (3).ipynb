# %%
import pandas as pd
import csv
import re
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
import gensim
from gensim import corpora, models
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import time
from pprint import pprint

stemmer = SnowballStemmer("english") # the stopwords 
def remain_english(line):
    rule =re.compile("[^a-z^A-Z]")
    line = rule.sub('',line)
    return line
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v')) # remain problems

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(str(text)) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
#             result.append(lemmatize_stemming(token))
            result.append(remain_english(lemmatize_stemming((token))).lower()) # take out not english and return into verb, and lower it 
    return result

# %%
# read file into pandas
import pandas as pd
fileGP = r'C:\Users\zmz22\Desktop\EntertainmentReview.csv'
fileApple = r'C:\Users\zmz22\Desktop\apple-entertainment-reviews.csv'

df1 = pd.read_csv(fileGP)
df2 = pd.read_csv(fileApple)

# %%
df1
# Out:
#                                                       id  \
# 0      gp:AOqpTOHx5mDMTC_RoU2oWdCReTcRszMwDwixD_Hwb4h...
# 1      gp:AOqpTOFUso0OcP5zQNlXoCjUpTo5YRFdXP0rSQ8yhiY...
# 2      gp:AOqpTOFdNhtdh30mbEKBjgShZ__PvRM30vQd8EYK_f5...
# 3      gp:AOqpTOFSrtghveiUQxW2NtaAuSPfxo6KfRQqIGWYkL_...
# 4      gp:AOqpTOGLEPK_fwTnCD4ofyirS7jKe7pBBWdLN97VyNx...
# 5      gp:AOqpTOGfscgkz5PDI96WMkjo7jCki2nMnXYn_MPtk5U...
# 6      gp:AOqpTOHrEmkKTbZjw8WGkkc_uR6v9_g8Y9d3AUL94WX...
# 7      gp:AOqpTOENMIJzr9R5PKdgAzuYGzpIdSAvOf9nglCrvkb...
# 8      gp:AOqpTOFTYJ9Drnm68TyVA2yV1nzDzGCI1AU84eEMWgr...
# 9      gp:AOqpTOEot0aeKLtlSV-xCiNI2rRLkPWq_R5iP5cPRKU...
# 10     gp:AOqpTOFomISckGOxEvIMoYWc9y_-pky3ypMuefaxC0h...
# 11     gp:AOqpTOFlyGTZPLai-zy3BoFBxUw7TCCwTDZWyPIkvOp...
# 12     gp:AOqpTOFy1Zt4OBIkfVNQ77rwxB6lSgO74XEnJa4vC6V...
# 13     gp:AOqpTOGKD3bPa2s9MkBIhNd1yd5_fqew1DfYtJ-ds8m...
# 14     gp:AOqpTOHDYgRddF5oxZLCRYSZ1ynxMb39FB_TtDxGiAS...
# 15     gp:AOqpTOHerwZnw6MpG0B6_OA_gYesWPNa8jIkc8O9f0Z...
# 16     gp:AOqpTOE68eBGp3tKYCduDwPINPtKWzrKQSmeLPnywbE...
# 17     gp:AOqpTOG_z4touMZ0cFQMxEsjyNG1Cqa08AfOf7AK9Ht...
# 18     gp:AOqpTOGA3qD0pi4oaFtmCjvcihp1zyhdxtR9HzlBgVn...
# 19     gp:AOqpTOGEprrt3hrC6une4Im4nDvSNfZtooqFKfwbuCy...
# 20     gp:AOqpTOGfsJHT7ohVttWaDDhkzXoYMPgrxJxiT-zs__g...
# 21     gp:AOqpTOHMpvh_A3N8m01F36uxbAZKNWizmB3cU6VC0Sz...
# 22     gp:AOqpTOHPamp-oYSGCTHkVAZNnj4YC7NsSpDXdRq5CKK...
# 23     gp:AOqpTOGUixr9whb8g1UqbHdV28sNYTkrc8JjdJzvdPD...
# 20327  gp:AOqpTOENnkKfugplnUhBIv2lRgmcHRrwunoKPiC60MA...
# 20328  gp:AOqpTOF4Qu5PE119ma0BPAVWQ7h4VGOtmeqDAJqzIc0...
# 20329  gp:AOqpTOE3jDFnQf7jIQigFOPTSpZdw7zQaDN5keZ3Hzr...
# 20330  gp:AOqpTOGAlbfgGddxNzi90F76ZpowBvCOvCLb8AQDay8...
# 20331  gp:AOqpTOGI4OsTF4_JEWNf4Te1uL6lmH_mtvGlg5bKA0R...
# 20332  gp:AOqpTOG6bC1_2MLy3DTAB4uhr9MK574T31-obdmUk8D...
#
#                    userName  \
# 0         Aditya Chaturvedi
# 1              Ray Hoffmann
# 2            hafizul haikal
# 3                Marco Polo
# 4              Damon Wilson
# 5                       NaN
# 6                   Rob Ski
# 7                       NaN
# 8      GSF Incorporated Inc
# 9               Michael Jac
# 10            Brad Beadling
# 11           Michael Kaplan
# 12                      J P
# 13                    p m j
# 14                      NaN
# 15            Johnny Joyner
# 16              Bryan Jones
# 17          Marjotie Chavez
# 18              Sir Charles
# 19                      NaN
# 20            Kashanya Ward
# 21        Veronica Ellerbee
# 22                 Lucas Lo
# 23           mitchell Ginda
# 24                      NaN
# 25                      NaN
# 26         PUNITAnv PARASHA
# 27                      NaN
# 28             Vikas Sharma
# 29               June Szulc
# ...                     ...
# 20303                   NaN
# 20304                   NaN
# 20305                   NaN
# 20306                   NaN
# 20307            Tracy Vera
# 20308       Austin Kirkland
# 20309            Yoga Ezhil
# 20310                   NaN
# 20311                   NaN
# 20312           Piper Jones
# 20313         matthew huang
# 20314           Katy Castro
# 20315          Jessica Hull
# 20316   J. Fernando Hidalgo
# 20317                   NaN
# 20318                   NaN
# 20319                   NaN
# 20320                   NaN
# 20321                   NaN
# 20322                   NaN
# 20323  Jennifer Collingwood
# 20324        Sophia Bassett
# 20325                   NaN
# 20326                   NaN
# 20327           Anil Bhosle
# 20328        Mohamed Khrais
# 20329                   NaN
# 20330                   NaN
# 20331    mohd suhaize hasim
# 20332      Mauritia le Roux
#
#                                                userImage                date  \
# 0      https://lh3.googleusercontent.com/a-/AAuE7mDPi...   December 13, 2018
# 1      https://lh6.googleusercontent.com/-Te_6Jf75j1k...      March 21, 2018
# 2      https://lh3.googleusercontent.com/a-/AAuE7mCcg...   December 17, 2018
# 3      https://lh3.googleusercontent.com/a-/AAuE7mBVN...   November 14, 2018
# 4      https://lh6.googleusercontent.com/-zo5k4L7h8f4...   December 26, 2018
# 5      https://lh3.googleusercontent.com/-_Y15f94PkGQ...    December 1, 2018
# 6      https://lh5.googleusercontent.com/-HGBxtYOcr8g...    December 2, 2018
# 7      https://lh3.googleusercontent.com/-mbsdIq7V3Yc...   November 24, 2018
# 8      https://lh3.googleusercontent.com/a-/AAuE7mAJ2...    October 30, 2018
# 9      https://lh3.googleusercontent.com/a-/AAuE7mDz5...     October 8, 2018
# 10     https://lh6.googleusercontent.com/-Xf8sQEOe2lA...   November 11, 2018
# 11     https://lh3.googleusercontent.com/a-/AAuE7mAOH...     October 6, 2018
# 20309  https://play.google.com/store/apps/details?id=...      5   NaN
# 20310  https://play.google.com/store/apps/details?id=...      5   NaN
# 20311  https://play.google.com/store/apps/details?id=...      5   NaN
# 20312  https://play.google.com/store/apps/details?id=...      5   NaN
# 20313  https://play.google.com/store/apps/details?id=...      5   NaN
# 20314  https://play.google.com/store/apps/details?id=...      5   NaN
# 20315  https://play.google.com/store/apps/details?id=...      5   NaN
# 20316  https://play.google.com/store/apps/details?id=...      5   NaN
# 20317  https://play.google.com/store/apps/details?id=...      5   NaN
# 20318  https://play.google.com/store/apps/details?id=...      5   NaN
# 20319  https://play.google.com/store/apps/details?id=...      5   NaN
# 20320  https://play.google.com/store/apps/details?id=...      4   NaN
# 20321  https://play.google.com/store/apps/details?id=...      5   NaN
# 20322  https://play.google.com/store/apps/details?id=...      5   NaN
# 20323  https://play.google.com/store/apps/details?id=...      5   NaN
# 20324  https://play.google.com/store/apps/details?id=...      5   NaN
# 20325  https://play.google.com/store/apps/details?id=...      5   NaN
# 20326  https://play.google.com/store/apps/details?id=...      5   NaN
# 20327  https://play.google.com/store/apps/details?id=...      5   NaN
# 20328  https://play.google.com/store/apps/details?id=...      4   NaN
# 20329  https://play.google.com/store/apps/details?id=...      5   NaN
# 20330  https://play.google.com/store/apps/details?id=...      5   NaN
# 20331  https://play.google.com/store/apps/details?id=...      1   NaN
# 20332  https://play.google.com/store/apps/details?id=...      5   NaN
#
#                                                     text          replyDate  \
# 0                Misleading, nonsense app it's of no use                NaN
# 1                             Unable to select language.                NaN
# 2      I hope you can add speed control and i wish i ...                NaN
# 3      The light change doesn't work it says bar erro...                NaN
# 4      For some stupid reason you HAVE TO allow this ...                NaN
# 5      Waste of time been trying to download Ophelia ...                NaN
# 6      Think holystone and dgi should make their own ...                NaN
# 7      Failed to install (twice) on Galaxy S4, "Progr...                NaN
# 8      Doesn't work with Google maps. When you try to...                NaN
# 9      Cannot see location when using app only showed...                NaN
# 10          Does not work, keep getting abnormal message                NaN
# 11                     it doesn't work...returning drone                NaN
# 12        Can't open keep getting abnormal/quit message!                NaN
# 13                                      Abnormal message                NaN
# 14     Best drone for the money on market and the bes...                NaN
# 15       You have so many pop-ups on this app is no good                NaN
# 16     This is not the original app no where to sign ...                NaN
# 17                             This is not the right one                NaN
# 18            I just downloaded in to my phone,11/1/2018                NaN
# 19                                               Oh yeah                NaN
# 20                                                its ok                NaN
# 21     terrible i deleted this one and downloaded the...                NaN
# 22                                          Lovely app!😊                NaN
# 23                                           Terbaik jer                NaN
# 24                                             Nice app!                NaN
# 25     The only thing is that I can do is My only con...                NaN
# 26             I have no idea about dounuts I love theme                NaN
# 27                                  Where are the cupons                NaN
# 28     Nonsense app lands you always on privacy polic...                NaN
# 29                                      Dukin On the run                NaN
# ...                                                  ...                ...
# 20303             To many adds but besides that #AMAZING                NaN
# 20304  I love the app because it is interesting and i...                NaN
# 20305  I LOVE THIS GAME!! it is so relaxing and amazing.                NaN
# 20306  its so gooood and the bit at the end is sooo s...                NaN
# 20307      I love the video when you finish your artwork                NaN
# 20308  This game is sooooooo fun i played it for hour...                NaN
# 20309                        it is very nice. it is fun.  December 18, 2018
# 20310   Amazing game' have ever played it is so relaxing                NaN
# 20311  I like unicorn because it's a fun app and it's...                NaN
# 20312                               It was fun and easy.                NaN
# 20313                                         It's a god                NaN
# 20314    Would like to see Sonic from tge original game.                NaN
# 20315             I love this app! It's REALLY relaxing.                NaN
# 20316  Its a nice coloring game and nice detail love ...                NaN
# 20317  It's a really cute application, I really liked...                NaN
# 20318                          I like what it looks like                NaN
# 20319       Is very relaxing and I really like it😊😊😻💚💛💙💜                NaN
# 20320        It's a great time passer,Highly recommended                NaN
# 20321               This app is so cool. And vary coming                NaN
# 20322  I don't know what to say......blablabla it's f...                NaN
# 20323                       I love coloring so I love it                NaN
# 20324                                     I LOVE IT!!!!!                NaN
# 20325  I love this app so much. Because i love colouring                NaN
# 20326   Good and the best pixel art on mobile phone ever                NaN
# 20327   Good easy with number my daughter likes it a lot                NaN
# 20328  I think it is a good app for kids to have fun ...                NaN
# 20329  I am actually ok with the ads . it's cute too:);)                NaN
# 20330                                         Artistic!!                NaN
# 20331                                          Baddddd!!                NaN
# 20332                                        I love it 😙                NaN
#
#       replyText     ...     Unnamed: 15  Unnamed: 16 Unnamed: 17  Unnamed: 18  \
# 0           NaN     ...             NaN          NaN         NaN          NaN
# 1           NaN     ...             NaN          NaN         NaN          NaN
# 2           NaN     ...             NaN          NaN         NaN          NaN
# 3           NaN     ...             NaN          NaN         NaN          NaN
# 4           NaN     ...             NaN          NaN         NaN          NaN
# 5           NaN     ...             NaN          NaN         NaN          NaN
# 6           NaN     ...             NaN          NaN         NaN          NaN
# 7           NaN     ...             NaN          NaN         NaN          NaN
# 8           NaN     ...             NaN          NaN         NaN          NaN
# 9           NaN     ...             NaN          NaN         NaN          NaN
# 10          NaN     ...             NaN          NaN         NaN          NaN
# 11          NaN     ...             NaN          NaN         NaN          NaN
# 12          NaN     ...             NaN          NaN         NaN          NaN
# 13          NaN     ...             NaN          NaN         NaN          NaN
# 14          NaN     ...             NaN          NaN         NaN          NaN
# 15          NaN     ...             NaN          NaN         NaN          NaN
# 16          NaN     ...             NaN          NaN         NaN          NaN
# 17          NaN     ...             NaN          NaN         NaN          NaN
# 18          NaN     ...             NaN          NaN         NaN          NaN
# 19          NaN     ...             NaN          NaN         NaN          NaN
# 20          NaN     ...             NaN          NaN         NaN          NaN
# 21          NaN     ...             NaN          NaN         NaN          NaN
# 22          NaN     ...             NaN          NaN         NaN          NaN
# 23          NaN     ...             NaN          NaN         NaN          NaN
# 24          NaN     ...             NaN          NaN         NaN          NaN
# 25          NaN     ...             NaN          NaN         NaN          NaN
# 26          NaN     ...             NaN          NaN         NaN          NaN
# 27          NaN     ...             NaN          NaN         NaN          NaN
# 28          NaN     ...             NaN          NaN         NaN          NaN
# 29          NaN     ...             NaN          NaN         NaN          NaN
# ...         ...     ...             ...          ...         ...          ...
# 20303       NaN     ...             NaN          NaN         NaN          NaN
# 20304       NaN     ...             NaN          NaN         NaN          NaN
# 20305       NaN     ...             NaN          NaN         NaN          NaN
# 20306       NaN     ...             NaN          NaN         NaN          NaN
# 20307       NaN     ...             NaN          NaN         NaN          NaN
# 20308       NaN     ...             NaN          NaN         NaN          NaN
# 20309    ❤️💛💚💙💜     ...             NaN          NaN         NaN          NaN
# 20310       NaN     ...             NaN          NaN         NaN          NaN
# 20311       NaN     ...             NaN          NaN         NaN          NaN
# 20312       NaN     ...             NaN          NaN         NaN          NaN
# 20313       NaN     ...             NaN          NaN         NaN          NaN
# 20314       NaN     ...             NaN          NaN         NaN          NaN
# 20315       NaN     ...             NaN          NaN         NaN          NaN
# 20316       NaN     ...             NaN          NaN         NaN          NaN
# 20317       NaN     ...             NaN          NaN         NaN          NaN
# 20318       NaN     ...             NaN          NaN         NaN          NaN
# 20319       NaN     ...             NaN          NaN         NaN          NaN
# 20320       NaN     ...             NaN          NaN         NaN          NaN
# 20321       NaN     ...             NaN          NaN         NaN          NaN
# 20322       NaN     ...             NaN          NaN         NaN          NaN
# 20323       NaN     ...             NaN          NaN         NaN          NaN
# 20324       NaN     ...             NaN          NaN         NaN          NaN
# 20325       NaN     ...             NaN          NaN         NaN          NaN
# 20326       NaN     ...             NaN          NaN         NaN          NaN
# 20327       NaN     ...             NaN          NaN         NaN          NaN
# 20328       NaN     ...             NaN          NaN         NaN          NaN
# 20329       NaN     ...             NaN          NaN         NaN          NaN
# 20330       NaN     ...             NaN          NaN         NaN          NaN
# 20331       NaN     ...             NaN          NaN         NaN          NaN
# 20332       NaN     ...             NaN          NaN         NaN          NaN
#
#       Unnamed: 19 Unnamed: 20 Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0             NaN         NaN         NaN          NaN          NaN
# 1             NaN         NaN         NaN          NaN          NaN
# 2             NaN         NaN         NaN          NaN          NaN
# 3             NaN         NaN         NaN          NaN          NaN
# 4             NaN         NaN         NaN          NaN          NaN
# 5             NaN         NaN         NaN          NaN          NaN
# 6             NaN         NaN         NaN          NaN          NaN
# 7             NaN         NaN         NaN          NaN          NaN
# 8             NaN         NaN         NaN          NaN          NaN
# 9             NaN         NaN         NaN          NaN          NaN
# 10            NaN         NaN         NaN          NaN          NaN
# 11            NaN         NaN         NaN          NaN          NaN
# 12            NaN         NaN         NaN          NaN          NaN
# 13            NaN         NaN         NaN          NaN          NaN
# 14            NaN         NaN         NaN          NaN          NaN
# 15            NaN         NaN         NaN          NaN          NaN
# 16            NaN         NaN         NaN          NaN          NaN
# 17            NaN         NaN         NaN          NaN          NaN
# 18            NaN         NaN         NaN          NaN          NaN
# 19            NaN         NaN         NaN          NaN          NaN
# 20            NaN         NaN         NaN          NaN          NaN
# 21            NaN         NaN         NaN          NaN          NaN
# 22            NaN         NaN         NaN          NaN          NaN
# 23            NaN         NaN         NaN          NaN          NaN
# 24            NaN         NaN         NaN          NaN          NaN
# 25            NaN         NaN         NaN          NaN          NaN
# 26            NaN         NaN         NaN          NaN          NaN
# 27            NaN         NaN         NaN          NaN          NaN
# 28            NaN         NaN         NaN          NaN          NaN
# 29            NaN         NaN         NaN          NaN          NaN
# ...           ...         ...         ...          ...          ...
# 20303         NaN         NaN         NaN          NaN          NaN
# 20304         NaN         NaN         NaN          NaN          NaN
# 20305         NaN         NaN         NaN          NaN          NaN
# 20306         NaN         NaN         NaN          NaN          NaN
# 20307         NaN         NaN         NaN          NaN          NaN
# 20308         NaN         NaN         NaN          NaN          NaN
# 20309         NaN         NaN         NaN          NaN          NaN
# 20310         NaN         NaN         NaN          NaN          NaN
# 20311         NaN         NaN         NaN          NaN          NaN
# 20312         NaN         NaN         NaN          NaN          NaN
# 20313         NaN         NaN         NaN          NaN          NaN
# 20314         NaN         NaN         NaN          NaN          NaN
# 20315         NaN         NaN         NaN          NaN          NaN
# 20316         NaN         NaN         NaN          NaN          NaN
# 20317         NaN         NaN         NaN          NaN          NaN
# 20318         NaN         NaN         NaN          NaN          NaN
# 20319         NaN         NaN         NaN          NaN          NaN
# 20320         NaN         NaN         NaN          NaN          NaN
# 20321         NaN         NaN         NaN          NaN          NaN
# 20322         NaN         NaN         NaN          NaN          NaN
# 20323         NaN         NaN         NaN          NaN          NaN
# 20324         NaN         NaN         NaN          NaN          NaN
# 20325         NaN         NaN         NaN          NaN          NaN
# 20326         NaN         NaN         NaN          NaN          NaN
# 20327         NaN         NaN         NaN          NaN          NaN
# 20328         NaN         NaN         NaN          NaN          NaN
# 20329         NaN         NaN         NaN          NaN          NaN
# 20330         NaN         NaN         NaN          NaN          NaN
# 20331         NaN         NaN         NaN          NaN          NaN
# 20332         NaN         NaN         NaN          NaN          NaN
#
#       Unnamed: 24
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# ...           ...
# 20303         NaN
# 20304         NaN
# 20305         NaN
# 20306         NaN
# 20307         NaN
# 20308         NaN
# 20309         NaN
# 20310         NaN
# 20311         NaN
# 20312         NaN
# 20313         NaN
# 20314         NaN
# 20315         NaN
# 20316         NaN
# 20317         NaN
# 20318         NaN
# 20319         NaN
# 20320         NaN
# 20321         NaN
# 20322         NaN
# 20323         NaN
# 20324         NaN
# 20325         NaN
# 20326         NaN
# 20327         NaN
# 20328         NaN
# 20329         NaN
# 20330         NaN
# 20331         NaN
# 20332         NaN
#
# [20333 rows x 25 columns]

# %%
import nltk
nltk.download('vader_lexicon')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\zmz22\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\zmz22\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
gpNum = df1.count()['text']
ApNum = df2.count()['text'] # text(reviews) number from apple
sid = SentimentIntensityAnalyzer()
text_num = gpNum + ApNum
# text_num = 5500
documentNeg=[]
documentPos=[]
inconsistantNum1 = 0 # inconsistant reviews number in low rating reviews
inconsistantNum2 = 0
for i in range(gpNum):
    if(df1.score[i]<3): # low rating reviews
#         print(sid.polarity_scores(df1.text[i])['neg'])
        if(sid.polarity_scores(str(df1.text[i]))['pos'] > 0.5): # 如果是这条评论的sensitive分析分数显示这条评论其实是负面的,threhold = 0.5
            inconsistantNum1 += 1
        else:
            documentNeg.append(df1.text[i])             

    if(df1.score[i]>3): # high rating reviews
        if(sid.polarity_scores(str(df1.text[i]))['neg'] > 0.5): # if the neg score is high, not use this review,threhold = 0.5
            inconsistantNum2 += 1
        else:
            documentPos.append(df1.text[i]) 
            
for j in range(ApNum):
    if(df2.score[j]<3): # low rating reviews
        if(sid.polarity_scores(str(df2.text[j]))['pos'] > 0.5): # 如果是这条评论的sensitive分析分数显示这条评论其实是负面的,threhold = 0.5
            inconsistantNum1 += 1
        else:
            documentNeg.append(df2.text[j])             
    if(df2.score[j]>3): # low rating reviews
        if(sid.polarity_scores(str(df2.text[j]))['neg'] > 0.5): # if the neg score is high, not use this review,threhold = 0.5
            inconsistantNum2 += 1
        else:
            documentPos.append(df2.text[j])      
                        
print('number of reviews text:',text_num)
print('number of neg:',len(documentNeg))
print('number of inconsistant neg reviews text(actually a pos reviews):',inconsistantNum1)
print('number of pos:',len(documentPos))
print('number of inconsistant pos reviews text(actually an neg reviews):',inconsistantNum2)
# Out:
# number of reviews text: 479082
# number of neg: 123068
# number of inconsistant neg reviews text(actually a pos reviews): 903
# number of pos: 315513
# number of inconsistant pos reviews text(actually an neg reviews): 1113

# %%
# negtive reviews analyse
document = documentNeg
doc_clean = [preprocess(doc) for doc in document]

dictionary = corpora.Dictionary(doc_clean)

# 使用上面的词典，将转换文档列表（语料）变成 DT 矩阵
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
Lda = gensim.models.ldamodel.LdaModel
print('object num',len(doc_term_matrix))
start = time.time()
lda_model = gensim.models.LdaMulticore(doc_term_matrix, num_topics=10, id2word=dictionary, passes=100, workers=4)
# result = lda_model.print_topics(num_words=10)
end = time.time()
print ('Fitting Time:',end-start)
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# print(result)
# Out:
# object num 123068
# Fitting Time: 2980.296327829361
# Topic: 0
# Words: 0.052*"screen" + 0.030*"pictur" + 0.022*"color" + 0.021*"button" + 0.016*"time" + 0.016*"save" + 0.016*"video" + 0.013*"go" + 0.013*"click" + 0.013*"like"
# Topic: 1
# Words: 0.047*"like" + 0.024*"say" + 0.023*"game" + 0.021*"think" + 0.019*"thing" + 0.019*"play" + 0.016*"sound" + 0.016*"want" + 0.015*"look" + 0.015*"peopl"
# Topic: 2
# Words: 0.063*"watch" + 0.024*"time" + 0.023*"episod" + 0.021*"video" + 0.020*"play" + 0.020*"show" + 0.016*"work" + 0.016*"connect" + 0.015*"stream" + 0.015*"commerci"
# Topic: 3
# Words: 0.037*"star" + 0.030*"review" + 0.020*"time" + 0.018*"read" + 0.014*"love" + 0.012*"point" + 0.012*"like" + 0.011*"updat" + 0.010*"get" + 0.010*"rat"
# Topic: 4
# Words: 0.016*"featur" + 0.015*"updat" + 0.013*"version" + 0.012*"like" + 0.012*"function" + 0.011*"user" + 0.011*"remot" + 0.010*"need" + 0.010*"control" + 0.009*"better"
# Topic: 5
# Words: 0.097*"movi" + 0.039*"show" + 0.025*"download" + 0.025*"list" + 0.024*"search" + 0.022*"watch" + 0.013*"want" + 0.012*"avail" + 0.009*"theater" + 0.009*"locat"
# Topic: 6
# Words: 0.182*"" + 0.104*"game" + 0.096*"wast" + 0.059*"time" + 0.039*"money" + 0.028*"play" + 0.025*"stupid" + 0.016*"worst" + 0.015*"crap" + 0.013*"hate"
# Topic: 7
# Words: 0.055*"free" + 0.046*"money" + 0.042*"pay" + 0.031*"subscript" + 0.027*"purchas" + 0.025*"month" + 0.022*"want" + 0.020*"charg" + 0.019*"cancel" + 0.015*"download"
# Topic: 8
# Words: 0.026*"ticket" + 0.024*"time" + 0.021*"work" + 0.019*"tri" + 0.019*"say" + 0.019*"account" + 0.015*"servic" + 0.014*"email" + 0.013*"sign" + 0.013*"error"
# Topic: 9
# Words: 0.138*"work" + 0.074*"updat" + 0.074*"crash" + 0.048*"iphon" + 0.043*"open" + 0.024*"time" + 0.024*"ipad" + 0.016*"download" + 0.014*"version" + 0.014*"tri"

# %%
# positive
document = documentPos
doc_clean = [preprocess(doc) for doc in document]

dictionary = corpora.Dictionary(doc_clean)
# 使用上面的词典，将转换文档列表（语料）变成 DT 矩阵
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
Lda = gensim.models.ldamodel.LdaModel
print('object num',len(doc_term_matrix))
start = time.time()
lda_model = gensim.models.LdaMulticore(doc_term_matrix, num_topics=10, id2word=dictionary, passes=100, workers=4)
# result = lda_model.print_topics(num_words=10)
end = time.time()
print ('Fitting Time:',end-start)
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# print(result)
# Out:
# object num 315513
# Fitting Time: 6002.828174114227
# Topic: 0
# Words: 0.070*"" + 0.024*"remot" + 0.022*"ghost" + 0.021*"music" + 0.020*"hous" + 0.017*"room" + 0.017*"emoji" + 0.016*"night" + 0.014*"song" + 0.012*"control"
# Topic: 1
# Words: 0.262*"love" + 0.039*"friend" + 0.036*"funni" + 0.024*"kid" + 0.023*"great" + 0.021*"laugh" + 0.020*"famili" + 0.018*"make" + 0.015*"entertain" + 0.015*"year"
# Topic: 2
# Words: 0.163*"best" + 0.042*"life" + 0.025*"world" + 0.025*"skin" + 0.024*"help" + 0.022*"thank" + 0.016*"app" + 0.008*"minecraft" + 0.008*"awsom" + 0.008*"learn"
# Topic: 3
# Words: 0.080*"great" + 0.038*"worth" + 0.037*"free" + 0.029*"ticket" + 0.026*"money" + 0.024*"purchas" + 0.023*"version" + 0.020*"buy" + 0.017*"time" + 0.017*"price"
# Topic: 4
# Words: 0.032*"say" + 0.023*"time" + 0.021*"work" + 0.017*"updat" + 0.015*"know" + 0.014*"go" + 0.013*"problem" + 0.013*"like" + 0.011*"thing" + 0.011*"phone"
# Topic: 5
# Words: 0.115*"game" + 0.044*"love" + 0.034*"play" + 0.032*"like" + 0.032*"color" + 0.019*"great" + 0.019*"pictur" + 0.018*"nice" + 0.014*"wish" + 0.013*"option"
# Topic: 6
# Words: 0.163*"good" + 0.054*"star" + 0.036*"review" + 0.029*"pretti" + 0.026*"read" + 0.022*"card" + 0.020*"write" + 0.019*"give" + 0.017*"rat" + 0.015*"point"
# Topic: 7
# Words: 0.113*"like" + 0.049*"cool" + 0.032*"thing" + 0.031*"think" + 0.031*"sound" + 0.025*"anim" + 0.025*"look" + 0.021*"stuff" + 0.018*"peopl" + 0.017*"need"
# Topic: 8
# Words: 0.040*"watch" + 0.025*"movi" + 0.023*"show" + 0.021*"great" + 0.014*"video" + 0.013*"like" + 0.012*"work" + 0.010*"episod" + 0.010*"ipad" + 0.010*"abl"
# Topic: 9
# Words: 0.063*"awesom" + 0.057*"work" + 0.053*"easi" + 0.043*"great" + 0.033*"amaz" + 0.027*"recommend" + 0.017*"high" + 0.016*"look" + 0.015*"perfect" + 0.013*"simpl"
